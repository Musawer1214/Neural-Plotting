# %%
# Cell 1: Install tools and clone Neural Plotting
# !git clone https://github.com/Musawer1214/Neural-Plotting.git
# !apt-get update -y
# !apt-get install -y texlive texlive-latex-extra texlive-fonts-recommended texlive-pictures poppler-utils

# %%
# Cell 2: Enter Neural Plotting and verify the expected folders/files
# %cd /content/Neural-Plotting
# !ls

# %%
# Cell 3: Inspect the repo-native YOLOv12 example
# !sed -n '1,220p' /content/Neural-Plotting/pyexamples/yolov12.py

# %%
# Cell 4: Generate the LaTeX file from the repo-native YOLOv12 Python script
# %cd /content/Neural-Plotting/pyexamples
# !python yolov12.py
# !ls -lh yolov12.*

# %%
# Cell 5: Compile the LaTeX file to PDF
# %cd /content/Neural-Plotting/pyexamples
# !pdflatex -interaction=nonstopmode -halt-on-error yolov12.tex

# %%
# Cell 6: Convert the generated PDF to PNG for preview inside Colab
# !pdftoppm -png /content/Neural-Plotting/pyexamples/yolov12.pdf /content/Neural-Plotting/pyexamples/yolov12_page

# %%
# Cell 7: Display the first page as an image inside Colab
from IPython.display import Image, display
display(Image(filename="/content/Neural-Plotting/pyexamples/yolov12_page-1.png"))

# %%
# Cell 8: Download the final PDF
from google.colab import files
files.download('/content/Neural-Plotting/pyexamples/yolov12.pdf')

# %%
# Cell 9: Optional - check all generated outputs
# !ls -lh /content/Neural-Plotting/pyexamples/yolov12*
